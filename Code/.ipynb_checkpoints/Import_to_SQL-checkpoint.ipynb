# %%
# import packages

import pandas as pd
import sqlalchemy as sa
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float, NVARCHAR, DateTime
import os
import glob

# %%
file = pd.read_excel('/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201503.xlsx')
display(file.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5296 entries, 0 to 5295
# Data columns (total 28 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Index                                                                5295 non-null   float64
#  1   Round                                                                5295 non-null   float64
#  2   Period                                                               5295 non-null   datetime64[ns]
#  3   City                                                                 5295 non-null   object
#  4   Age                                                                  5295 non-null   object
#  5   Gender                                                               5295 non-null   object
#  6   Annual Income                                                        5295 non-null   object
#  7   Assembly Constituency Name                                           5295 non-null   object
#  8   Educational Qualification                                            5295 non-null   object
#  9   No. of Family Members                                                5295 non-null   object
#  10  No. of Earning members in the family                                 5295 non-null   float64
#  11  Occupation of Respondent                                             5295 non-null   object
#  12  Perception on General Economic condition - compared to one year ago  5295 non-null   object
#  13  Outlook on General Economic condition - one year ahead               5295 non-null   object
#  14  Perception on Household income - compared to one year ago            5295 non-null   object
#  15  Outlook on Household income - one year ahead                         5295 non-null   object
#  16  Perception on Household spending - compared to one year ago          5295 non-null   object
#  17  Outlook on Household spending - one year ahead                       5295 non-null   object
#  18  Perception on essential spending - compared to one year ago          5295 non-null   object
#  19  Outlook on essential spending - one year ahead                       5295 non-null   object
#  20  Perception on non-essential spending - compared to one year ago      5295 non-null   object
#  21  Outlook on non-essential spending - one year ahead                   5295 non-null   object
#  22  Perception on Employment scenario - compared to one year ago         5295 non-null   object
#  23  Outlook on Employment scenario - one year ahead                      5295 non-null   object
#  24  Perception on General prices - compared to one year ago              5295 non-null   object
#  25  Outlook on General prices - one year ahead                           5295 non-null   object
#  26  Perception on Inflation - compared to one year ago                   4173 non-null   object
#  27  Outlook on Inflation - one year ahead                                3913 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(24)
# memory usage: 1.1+ MB
# None

# %%
# create SQL database

engine = create_engine('sqlite:////Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS.db', echo = True) # sqlite:////absolute/path/to/file.db

meta = MetaData()

CCS = Table(
    'CCS', meta
    ,Column('Index', Float)
    ,Column('Round', Float)
    ,Column('Period', DateTime)
    ,Column('City', NVARCHAR)
    ,Column('Age', NVARCHAR)
    ,Column('Gender', NVARCHAR)
    ,Column('Annual Income', NVARCHAR)
    ,Column('Assembly Constituency Name', NVARCHAR)
    ,Column('Educational Qualification', NVARCHAR)
    ,Column('No. of Family Members', NVARCHAR)
    ,Column('No. of Earning members in the family', Float)
    ,Column('Occupation of Respondent', NVARCHAR)
    ,Column('Perception on General Economic condition - compared to one year ago', NVARCHAR)
    ,Column('Outlook on General Economic condition - one year ahead', NVARCHAR)
    ,Column('Perception on Household income - compared to one year ago', NVARCHAR)
    ,Column('Outlook on Household income - one year ahead', NVARCHAR)
    ,Column('Perception on Household spending - compared to one year ago', NVARCHAR)
    ,Column('Outlook on Household spending - one year ahead', NVARCHAR)
    ,Column('Perception on essential spending - compared to one year ago', NVARCHAR)
    ,Column('Outlook on essential spending - one year ahead', NVARCHAR)
    ,Column('Perception on non-essential spending - compared to one year ago', NVARCHAR)
    ,Column('Outlook on non-essential spending - one year ahead', NVARCHAR)
    ,Column('Perception on Employment scenario - compared to one year ago', NVARCHAR)
    ,Column('Outlook on Employment scenario - one year ahead', NVARCHAR)
    ,Column('Perception on General prices - compared to one year ago', NVARCHAR)
    ,Column('Outlook on General prices - one year ahead', NVARCHAR)
    ,Column('Perception on Inflation - compared to one year ago', NVARCHAR)
    ,Column('Outlook on Inflation - one year ahead', NVARCHAR)
    )

meta.create_all(engine)
# Out:
# 2021-02-23 22:41:03,287 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-02-23 22:41:03,288 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:41:03,289 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-02-23 22:41:03,289 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:41:03,290 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CCS")
# 2021-02-23 22:41:03,291 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:41:03,292 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("CCS")
# 2021-02-23 22:41:03,292 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:41:03,294 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE "CCS" (
# 	"Index" FLOAT,
# 	"Round" FLOAT,
# 	"Period" DATETIME,
# 	"City" NVARCHAR,
# 	"Age" NVARCHAR,
# 	"Gender" NVARCHAR,
# 	"Annual Income" NVARCHAR,
# 	"Assembly Constituency Name" NVARCHAR,
# 	"Educational Qualification" NVARCHAR,
# 	"No. of Family Members" NVARCHAR,
# 	"No. of Earning members in the family" FLOAT,
# 	"Occupation of Respondent" NVARCHAR,
# 	"Perception on General Economic condition - compared to one year ago" NVARCHAR,
# 	"Outlook on General Economic condition - one year ahead" NVARCHAR,
# 	"Perception on Household income - compared to one year ago" NVARCHAR,
# 	"Outlook on Household income - one year ahead" NVARCHAR,
# 	"Perception on Household spending - compared to one year ago" NVARCHAR,
# 	"Outlook on Household spending - one year ahead" NVARCHAR,
# 	"Perception on essential spending - compared to one year ago" NVARCHAR,
# 	"Outlook on essential spending - one year ahead" NVARCHAR,
# 	"Perception on non-essential spending - compared to one year ago" NVARCHAR,
# 	"Outlook on non-essential spending - one year ahead" NVARCHAR,
# 	"Perception on Employment scenario - compared to one year ago" NVARCHAR,
# 	"Outlook on Employment scenario - one year ahead" NVARCHAR,
# 	"Perception on General prices - compared to one year ago" NVARCHAR,
# 	"Outlook on General prices - one year ahead" NVARCHAR,
# 	"Perception on Inflation - compared to one year ago" NVARCHAR,
# 	"Outlook on Inflation - one year ahead" NVARCHAR
# )
#
#
# 2021-02-23 22:41:03,295 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:41:03,296 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
root = r'/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS'

url = []
for root, dirs, files in os.walk(root):
    url += glob.glob(os.path.join(root, '*.xlsx'))
    display(url)
# Out:
# ['/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201503.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201811.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201903.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201606.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201611.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201703.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_202011.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201806.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_202007.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201509.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201909.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201905.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201712.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201705.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201512.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_202001.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201709.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201706.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201907.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201803.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201911.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201506.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_202003.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201603.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201711.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201612.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201805.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201809.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_202009.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201609.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_202005.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201812.xlsx']

# %%
for file in url:
    df = pd.read_excel(file)
    df.to_sql('CCS', con=engine, if_exists='append')
# Out:
# 2021-02-23 22:43:03,005 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CCS")
# 2021-02-23 22:43:03,005 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:03,019 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 22:43:03,099 INFO sqlalchemy.engine.base.Engine INSERT INTO "CCS" ("index", "Index", "Round", "Period", "City", "Age", "Gender", "Annual Income", "Assembly Constituency Name", "Educational Qualification", "No. of Family Members", "No. of Earning members in the family", "Occupation of Respondent", "Perception on General Economic condition - compared to one year ago", "Outlook on General Economic condition - one year ahead", "Perception on Household income - compared to one year ago", "Outlook on Household income - one year ahead", "Perception on Household spending - compared to one year ago", "Outlook on Household spending - one year ahead", "Perception on essential spending - compared to one year ago", "Outlook on essential spending - one year ahead", "Perception on non-essential spending - compared to one year ago", "Outlook on non-essential spending - one year ahead", "Perception on Employment scenario - compared to one year ago", "Outlook on Employment scenario - one year ahead", "Perception on General prices - compared to one year ago", "Outlook on General prices - one year ahead", "Perception on Inflation - compared to one year ago", "Outlook on Inflation - one year ahead") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 22:43:03,100 INFO sqlalchemy.engine.base.Engine ((0, 1.0, 23.0, '2015-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Batarayanapura', 'Below graduate', '5 and more', 2.0, 'Employed', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (1, 2.0, 23.0, '2015-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Batarayanapura', 'Below graduate', '5 and more', 5.0, 'House wife', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Decreased', 'Will decrease', 'Improved', 'Will improve', 'Decreased', 'Will increase', None, 'Will increase'), (2, 3.0, 23.0, '2015-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Batarayanapura', 'Graduate & above', '5 and more', 3.0, 'House wife', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Decreased', 'Will decrease', 'Worsened', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (3, 4.0, 23.0, '2015-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Batarayanapura', 'Up to primary', '3 or 4', 2.0, 'Employed', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Decreased', 'Will decrease', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (4, 5.0, 23.0, '2015-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Batarayanapura', 'Up to primary', '3 or 4', 4.0, 'House wife', 'Improved', 'Will improve', 'Decreased', 'Will decrease', 'Decreased', 'Will decrease', 'Increased', 'Will decrease', 'Decreased', 'Will decrease', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (5, 6.0, 23.0, '2015-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Batarayanapura', 'Up to primary', '5 and more', 1.0, 'House wife', 'Improved', 'Will improve', 'Decreased', 'Will increase', 'Increased', 'Remain the same', 'Increased', 'Will decrease', 'Decreased', 'Remain the same', 'Improved', 'Will improve', 'Increased', 'Will decrease', 'Increased', None), (6, 7.0, 23.0, '2015-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Batarayanapura', 'Up to primary', '5 and more', 2.0, 'House wife', 'Improved', 'Will improve', 'Decreased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (7, 8.0, 23.0, '2015-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bhuvaneshwarinagar', 'Up to primary', '3 or 4', 1.0, 'House wife', 'Remained the same', 'Will improve', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Remained the same', 'Will increase', 'Improved', 'Will improve', 'Remained the same', 'Remain the same', None, None)  ... displaying 10 of 5296 total bound parameter sets ...  (5294, 5295.0, 23.0, '2015-03-31 00:00:00.000000', 'Mumbai', '60  & above year', 'Male', 'Rs. 3 lakh to 5 lakh', 'SHANTI NAGAR', 'Below graduate', '5 and more', 1.0, 'Retired/Pensioners', 'Worsened', 'Will worsen', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Worsened', 'Will worsen', 'Increased', 'Will increase', 'Increased', 'Will increase'), (5295, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, N ...
# 2021-02-23 22:43:03,121 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 22:43:03,124 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-02-23 22:43:03,125 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:04,392 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CCS")
# 2021-02-23 22:43:04,393 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:04,403 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 22:43:04,485 INFO sqlalchemy.engine.base.Engine INSERT INTO "CCS" ("index", "Index", "Round", "Period", "City", "Age", "Gender", "Annual Income", "Assembly Constituency Name", "Educational Qualification", "No. of Family Members", "No. of Earning members in the family", "Occupation of Respondent", "Perception on General Economic condition - compared to one year ago", "Outlook on General Economic condition - one year ahead", "Perception on Household income - compared to one year ago", "Outlook on Household income - one year ahead", "Perception on Household spending - compared to one year ago", "Outlook on Household spending - one year ahead", "Perception on essential spending - compared to one year ago", "Outlook on essential spending - one year ahead", "Perception on non-essential spending - compared to one year ago", "Outlook on non-essential spending - one year ahead", "Perception on Employment scenario - compared to one year ago", "Outlook on Employment scenario - one year ahead", "Perception on General prices - compared to one year ago", "Outlook on General prices - one year ahead", "Perception on Inflation - compared to one year ago", "Outlook on Inflation - one year ahead") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 22:43:04,485 INFO sqlalchemy.engine.base.Engine ((0, 1.0, 45.0, '2018-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amaraiwadi', '10th Std-Below 12th Std', '5 and more', 2.0, 'House wife', 'Improved', 'Will improve', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Will improve', 'Remained the same', 'Remain the same', None, None), (1, 2.0, 45.0, '2018-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amaraiwadi', '5th Std-Below 10th Std', '5 and more', 1.0, 'House wife', 'Worsened', 'Will improve', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Remain the same', 'Remained the same', 'Will improve', 'Remained the same', 'Will increase', None, 'Remain the same'), (2, 3.0, 45.0, '2018-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amaraiwadi', '5th Std-Below 10th Std', '5 and more', 2.0, 'House wife', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (3, 4.0, 45.0, '2018-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', '10th Std-Below 12th Std', '3 or 4', 1.0, 'House wife', 'Worsened', 'Remain the same', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Worsened', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (4, 5.0, 45.0, '2018-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', '5th Std-Below 10th Std', '3 or 4', 2.0, 'House wife', 'Remained the same', 'Remain the same', 'Decreased', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (5, 6.0, 45.0, '2018-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', '5th Std-Below 10th Std', '5 and more', 2.0, 'House wife', 'Remained the same', 'Will improve', 'Decreased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (6, 7.0, 45.0, '2018-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', 'Graduate', '5 and more', 1.0, 'Unemployed', 'Improved', 'Will improve', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Increased', 'Remain the same', 'Increased', None), (7, 8.0, 45.0, '2018-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bapunagar', '10th Std-Below 12th Std', '5 and more', 1.0, 'Employed', 'Worsened', 'Remain the same', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase')  ... displaying 10 of 5327 total bound parameter sets ...  (5325, 5326.0, 45.0, '2018-11-30 00:00:00.000000', 'Trivandrum', '60  & above year', 'Male', 'Rs. 1 to less than 3 lakh', 'Thiruvananthapuram', 'Graduate', '3 or 4', 2.0, 'Self Employed/ Business', 'Worsened', 'Will worsen', 'Decreased', 'Remain the same', 'Remained the same', 'Remain the same', 'Increased', 'Remain the same', 'Remained the same', 'Remain the same', 'Worsened', 'Will worsen', 'Increased', 'Will increase', 'Increased', 'Will decrease'), (5326, No ...
# 2021-02-23 22:43:04,506 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 22:43:04,510 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-02-23 22:43:04,510 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:05,908 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CCS")
# 2021-02-23 22:43:05,908 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:05,919 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 22:43:05,997 INFO sqlalchemy.engine.base.Engine INSERT INTO "CCS" ("index", "Index", "Round", "Period", "City", "Age", "Gender", "Annual Income", "Assembly Constituency Name", "Educational Qualification", "No. of Family Members", "No. of Earning members in the family", "Occupation of Respondent", "Perception on General Economic condition - compared to one year ago", "Outlook on General Economic condition - one year ahead", "Perception on Household income - compared to one year ago", "Outlook on Household income - one year ahead", "Perception on Household spending - compared to one year ago", "Outlook on Household spending - one year ahead", "Perception on essential spending - compared to one year ago", "Outlook on essential spending - one year ahead", "Perception on non-essential spending - compared to one year ago", "Outlook on non-essential spending - one year ahead", "Perception on Employment scenario - compared to one year ago", "Outlook on Employment scenario - one year ahead", "Perception on General prices - compared to one year ago", "Outlook on General prices - one year ahead", "Perception on Inflation - compared to one year ago", "Outlook on Inflation - one year ahead") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 22:43:05,998 INFO sqlalchemy.engine.base.Engine ((0, 1.0, 47.0, '2019-03-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amaraiwadi', '5th Std-Below 10th Std', '5 and more', 4.0, 'House wife', 'Improved', 'Will improve', 'Remained the same', 'Will increase', 'Remained the same', 'Will decrease', 'Remained the same', 'Will increase', 'Remained the same', 'Will decrease', 'Improved', 'Will improve', 'Decreased', 'Will increase', None, 'Will increase'), (1, 2.0, 47.0, '2019-03-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amaraiwadi', 'Below 5th Std', '5 and more', 4.0, 'Daily worker', 'Remained the same', 'Will improve', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (2, 3.0, 47.0, '2019-03-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amaraiwadi', 'Illiterate', '3 or 4', 1.0, 'Daily worker', 'Worsened', 'Will worsen', 'Decreased', 'Will increase', 'Remained the same', 'Will increase', 'Remained the same', 'Will increase', 'Remained the same', 'Will increase', 'Worsened', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (3, 4.0, 47.0, '2019-03-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', '5th Std-Below 10th Std', '5 and more', 3.0, 'Unemployed', 'Remained the same', 'Remain the same', 'Increased', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will worsen', 'Increased', 'Will decrease', 'Increased', None), (4, 5.0, 47.0, '2019-03-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', '5th Std-Below 10th Std', '5 and more', 4.0, 'House wife', 'Improved', 'Remain the same', 'Decreased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (5, 6.0, 47.0, '2019-03-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', 'Below 5th Std', '5 and more', 2.0, 'House wife', 'Remained the same', 'Will improve', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Remained the same', 'Will increase', 'Remained the same', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will decrease', 'Increased', None), (6, 7.0, 47.0, '2019-03-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', 'Illiterate', '5 and more', 1.0, 'House wife', 'Worsened', 'Will worsen', 'Decreased', 'Will increase', 'Remained the same', 'Remain the same', 'Increased', 'Remain the same', 'Remained the same', 'Will increase', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Remained the same', 'Will increase'), (7, 8.0, 47.0, '2019-03-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bapunagar', '5th Std-Below 10th Std', '5 and more', 1.0, 'House wife', 'Worsened', 'Will improve', 'Decreased', 'Remain the same', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase')  ... displaying 10 of 5344 total bound parameter sets ...  (5342, 5343.0, 47.0, '2019-03-31 00:00:00.000000', 'Trivandrum', '60  & above year', 'Male', 'Rs. 5 lakh or more', 'Vattiyoorkavu', 'Graduate', '1 to 2', 2.0, 'Retired/Pensioners', 'Improved', 'Will improve', 'Decreased', 'Will increase', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Will improve', 'Remained the same', 'Remain the same', None, None ...
# 2021-02-23 22:43:06,019 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 22:43:06,022 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-02-23 22:43:06,023 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:07,267 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CCS")
# 2021-02-23 22:43:07,268 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:07,277 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 22:43:07,356 INFO sqlalchemy.engine.base.Engine INSERT INTO "CCS" ("index", "Index", "Round", "Period", "City", "Age", "Gender", "Annual Income", "Assembly Constituency Name", "Educational Qualification", "No. of Family Members", "No. of Earning members in the family", "Occupation of Respondent", "Perception on General Economic condition - compared to one year ago", "Outlook on General Economic condition - one year ahead", "Perception on Household income - compared to one year ago", "Outlook on Household income - one year ahead", "Perception on Household spending - compared to one year ago", "Outlook on Household spending - one year ahead", "Perception on essential spending - compared to one year ago", "Outlook on essential spending - one year ahead", "Perception on non-essential spending - compared to one year ago", "Outlook on non-essential spending - one year ahead", "Perception on Employment scenario - compared to one year ago", "Outlook on Employment scenario - one year ahead", "Perception on General prices - compared to one year ago", "Outlook on General prices - one year ahead", "Perception on Inflation - compared to one year ago", "Outlook on Inflation - one year ahead") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 22:43:07,356 INFO sqlalchemy.engine.base.Engine ((0, 1.0, 31.0, '2016-06-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Adugodi', 'Up to primary', '5 and more', 8.0, 'Daily worker', 'Worsened', 'Remain the same', 'Decreased', 'Will decrease', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (1, 2.0, 31.0, '2016-06-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bangalore', 'Below graduate', '1 to 2', 1.0, 'House wife', 'Improved', 'Will improve', 'Decreased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Decreased', 'Will increase', 'Worsened', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (2, 3.0, 31.0, '2016-06-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bangalore', 'Below graduate', '3 or 4', 1.0, 'House wife', 'Improved', 'Will improve', 'Decreased', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Decreased', 'Will decrease', 'Worsened', 'Will worsen', 'Increased', 'Remain the same', 'Increased', None), (3, 4.0, 31.0, '2016-06-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bangalore', 'Graduate & above', '3 or 4', 1.0, 'Self Employed/ Business', 'Improved', 'Will improve', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Decreased', 'Will decrease', 'Worsened', 'Will worsen', 'Increased', 'Will increase', 'Increased', 'Will increase'), (4, 5.0, 31.0, '2016-06-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bangalore', 'Up to primary', '1 to 2', 1.0, 'House wife', 'Remained the same', 'Will improve', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Remain the same', 'Decreased', 'Remain the same', 'Worsened', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (5, 6.0, 31.0, '2016-06-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bangalore', 'Up to primary', '3 or 4', 1.0, 'Employed', 'Improved', 'Will improve', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will decrease', 'Decreased', 'Will decrease', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (6, 7.0, 31.0, '2016-06-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bangalore', 'Up to primary', '3 or 4', 1.0, 'House wife', 'Improved', 'Will improve', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Decreased', 'Will decrease', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (7, 8.0, 31.0, '2016-06-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bangalore', 'Up to primary', '3 or 4', 1.0, 'House wife', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Decreased', 'Will decrease', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase')  ... displaying 10 of 5208 total bound parameter sets ...  (5206, 5207.0, 31.0, '2016-06-30 00:00:00.000000', 'Mumbai', '60  & above year', 'Male', 'Rs. 5 lakh or more', 'Dadar E', 'Up to primary', '5 and more', 1.0, 'Retired/Pensioners', 'Worsened', 'Will worsen', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Worsened', 'Will worsen', 'Remained the same', 'Remain the same', None, None), (5207, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, Non ...
# 2021-02-23 22:43:07,377 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 22:43:07,380 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-02-23 22:43:07,381 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:08,592 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CCS")
# 2021-02-23 22:43:08,592 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:08,602 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 22:43:08,672 INFO sqlalchemy.engine.base.Engine INSERT INTO "CCS" ("index", "Index", "Round", "Period", "City", "Age", "Gender", "Annual Income", "Assembly Constituency Name", "Educational Qualification", "No. of Family Members", "No. of Earning members in the family", "Occupation of Respondent", "Perception on General Economic condition - compared to one year ago", "Outlook on General Economic condition - one year ahead", "Perception on Household income - compared to one year ago", "Outlook on Household income - one year ahead", "Perception on Household spending - compared to one year ago", "Outlook on Household spending - one year ahead", "Perception on essential spending - compared to one year ago", "Outlook on essential spending - one year ahead", "Perception on non-essential spending - compared to one year ago", "Outlook on non-essential spending - one year ahead", "Perception on Employment scenario - compared to one year ago", "Outlook on Employment scenario - one year ahead", "Perception on General prices - compared to one year ago", "Outlook on General prices - one year ahead", "Perception on Inflation - compared to one year ago", "Outlook on Inflation - one year ahead") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 22:43:08,673 INFO sqlalchemy.engine.base.Engine ((0, 1.0, 33.0, '2016-11-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', '18', 'Below graduate', '3 or 4', 2.0, 'Unemployed', 'Remained the same', 'Will improve', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Decreased', 'Will decrease', 'Remained the same', 'Will improve', 'Increased', 'Will increase', 'Remained the same', 'Will increase'), (1, 2.0, 33.0, '2016-11-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', '44', 'Below graduate', '3 or 4', 2.0, 'Unemployed', 'Worsened', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Will decrease', 'Decreased', 'Remain the same', 'Remained the same', 'Remain the same', 'Worsened', 'Remain the same', 'Remained the same', 'Remain the same', None, None), (2, 3.0, 33.0, '2016-11-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', '44', 'Below graduate', '3 or 4', 2.0, 'Unemployed', 'Worsened', 'Will worsen', 'Decreased', 'Will decrease', 'Remained the same', 'Will decrease', 'Decreased', 'Will decrease', 'Decreased', 'Will decrease', 'Worsened', 'Will worsen', 'Decreased', 'Will decrease', None, None), (3, 4.0, 33.0, '2016-11-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bommanahalli', 'Below graduate', '3 or 4', 2.0, 'House wife', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (4, 5.0, 33.0, '2016-11-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bommanahalli', 'Below graduate', '3 or 4', 2.0, 'Self Employed/ Business', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (5, 6.0, 33.0, '2016-11-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bommanahalli', 'Below graduate', '5 and more', 4.0, 'House wife', 'Improved', 'Will improve', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (6, 7.0, 33.0, '2016-11-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bommanahalli', 'Up to primary', '1 to 2', 1.0, 'House wife', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Will improve', 'Remained the same', 'Will increase', None, 'Remain the same'), (7, 8.0, 33.0, '2016-11-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bommanahalli', 'Up to primary', '3 or 4', 2.0, 'House wife', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Remained the same', 'Will increase')  ... displaying 10 of 4687 total bound parameter sets ...  (4685, 4686.0, 33.0, '2016-11-30 00:00:00.000000', 'Mumbai', '60  & above year', 'Male', 'Rs. 1 to less than 3 lakh', 'Trombe Chitta Camp Vitthal Narayan Purva Marg,', 'Below graduate', '3 or 4', 1.0, 'Retired/Pensioners', 'Improved', 'Remain the same', 'Remained the same', 'Will decrease', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Worsened', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Remain the same'), (4686, None, None, None, None, None, None, None, None, None, None, None, None, N ...
# 2021-02-23 22:43:08,690 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 22:43:08,694 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-02-23 22:43:08,694 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:09,867 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CCS")
# 2021-02-23 22:43:09,868 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:09,877 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 22:43:09,951 INFO sqlalchemy.engine.base.Engine INSERT INTO "CCS" ("index", "Index", "Round", "Period", "City", "Age", "Gender", "Annual Income", "Assembly Constituency Name", "Educational Qualification", "No. of Family Members", "No. of Earning members in the family", "Occupation of Respondent", "Perception on General Economic condition - compared to one year ago", "Outlook on General Economic condition - one year ahead", "Perception on Household income - compared to one year ago", "Outlook on Household income - one year ahead", "Perception on Household spending - compared to one year ago", "Outlook on Household spending - one year ahead", "Perception on essential spending - compared to one year ago", "Outlook on essential spending - one year ahead", "Perception on non-essential spending - compared to one year ago", "Outlook on non-essential spending - one year ahead", "Perception on Employment scenario - compared to one year ago", "Outlook on Employment scenario - one year ahead", "Perception on General prices - compared to one year ago", "Outlook on General prices - one year ahead", "Perception on Inflation - compared to one year ago", "Outlook on Inflation - one year ahead") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 22:43:09,951 INFO sqlalchemy.engine.base.Engine ((0, 1.0, 35.0, '2017-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amara Jyothi English School, Room No. 1, Devasandra', 'Below graduate', '1 to 2', 1.0, 'House wife', 'Improved', 'Will improve', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Improved', 'Will improve', 'Increased', 'Remain the same', 'Remained the same', None), (1, 2.0, 35.0, '2017-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amara Jyothi English School, Room No. 1, Devasandra', 'Below graduate', '5 and more', 1.0, 'House wife', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (2, 3.0, 35.0, '2017-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amara Jyothi English School, Room No. 1, Devasandra', 'Below graduate', '5 and more', 3.0, 'Unemployed', 'Improved', 'Remain the same', 'Remained the same', 'Will increase', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (3, 4.0, 35.0, '2017-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amara Jyothi English School, Room No. 1, Devasandra', 'Graduate & above', '5 and more', 2.0, 'House wife', 'Improved', 'Will improve', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Improved', 'Will improve', 'Increased', 'Remain the same', 'Increased', None), (4, 5.0, 35.0, '2017-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Anupama English School , Shankramata Main Road, Kurubarahalli Bangalore-560086, Room No1', 'Below graduate', '3 or 4', 1.0, 'Unemployed', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Decreased', 'Remain the same', 'Worsened', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (5, 6.0, 35.0, '2017-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Anupama English School , Shankramata Main Road, Kurubarahalli Bangalore-560086, Room No1', 'Below graduate', '5 and more', 1.0, 'House wife', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Improved', 'Will improve', 'Decreased', 'Remain the same', None, None), (6, 7.0, 35.0, '2017-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Anupama English School , Shankramata Main Road, Kurubarahalli Bangalore-560086, Room No1', 'Below graduate', '5 and more', 1.0, 'House wife', 'Remained the same', 'Remain the same', 'Decreased', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Improved', 'Will improve', 'Remained the same', 'Will increase', None, 'Will increase'), (7, 8.0, 35.0, '2017-03-31 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Anupama English School , Shankramata Main Road, Kurubarahalli Bangalore-560086, Room No1', 'Below graduate', '5 and more', 2.0, 'House wife', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Remain the same', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased',  ...
# 2021-02-23 22:43:09,971 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 22:43:09,974 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-02-23 22:43:09,975 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:11,341 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CCS")
# 2021-02-23 22:43:11,341 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:11,352 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 22:43:11,432 INFO sqlalchemy.engine.base.Engine INSERT INTO "CCS" ("index", "Index", "Round", "Period", "City", "Age", "Gender", "Annual Income", "Assembly Constituency Name", "Educational Qualification", "No. of Family Members", "No. of Earning members in the family", "Occupation of Respondent", "Perception on General Economic condition - compared to one year ago", "Outlook on General Economic condition - one year ahead", "Perception on Household income - compared to one year ago", "Outlook on Household income - one year ahead", "Perception on Household spending - compared to one year ago", "Outlook on Household spending - one year ahead", "Perception on essential spending - compared to one year ago", "Outlook on essential spending - one year ahead", "Perception on non-essential spending - compared to one year ago", "Outlook on non-essential spending - one year ahead", "Perception on Employment scenario - compared to one year ago", "Outlook on Employment scenario - one year ahead", "Perception on General prices - compared to one year ago", "Outlook on General prices - one year ahead", "Perception on Inflation - compared to one year ago", "Outlook on Inflation - one year ahead") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 22:43:11,432 INFO sqlalchemy.engine.base.Engine ((0, 1.0, 57.0, '2020-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amaraiwadi', '5th Std-Below 10th Std', '5 and more', 1.0, 'House wife', 'Worsened', 'Will worsen', 'Decreased', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Worsened', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (1, 2.0, 57.0, '2020-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', '12th Std', '3 or 4', 2.0, 'House wife', 'Improved', 'Will improve', 'Decreased', 'Will increase', 'Remained the same', 'Will increase', 'Remained the same', 'Will increase', 'Remained the same', 'Will increase', 'Improved', 'Will improve', 'Decreased', 'Will increase', None, 'Will increase'), (2, 3.0, 57.0, '2020-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', '12th Std', '5 and more', 1.0, 'House wife', 'Worsened', 'Will improve', 'Decreased', 'Remain the same', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Decreased', 'Remain the same', 'Worsened', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (3, 4.0, 57.0, '2020-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', 'Below 5th Std', '3 or 4', 1.0, 'House wife', 'Improved', 'Will improve', 'Decreased', 'Will increase', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Worsened', 'Will improve', 'Increased', 'Remain the same', 'Increased', None), (4, 5.0, 57.0, '2020-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bapunagar', '10th Std-Below 12th Std', '3 or 4', 1.0, 'House wife', 'Worsened', 'Remain the same', 'Remained the same', 'Remain the same', 'Increased', 'Remain the same', 'Increased', 'Will decrease', 'Remained the same', 'Remain the same', 'Worsened', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (5, 6.0, 57.0, '2020-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Danilimda', '10th Std-Below 12th Std', '3 or 4', 1.0, 'House wife', 'Worsened', 'Will improve', 'Remained the same', 'Remain the same', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Decreased', 'Remain the same', 'Worsened', 'Remain the same', 'Increased', 'Remain the same', 'Increased', None), (6, 7.0, 57.0, '2020-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Danilimda', '5th Std-Below 10th Std', '3 or 4', 1.0, 'House wife', 'Worsened', 'Will improve', 'Decreased', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Worsened', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (7, 8.0, 57.0, '2020-11-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Danilimda', '5th Std-Below 10th Std', '3 or 4', 2.0, 'Employed', 'Worsened', 'Will improve', 'Decreased', 'Will increase', 'Remained the same', 'Remain the same', 'Decreased', 'Will increase', 'Remained the same', 'Remain the same', 'Worsened', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase')  ... displaying 10 of 5320 total bound parameter sets ...  (5318, 5319.0, 57.0, '2020-11-30 00:00:00.000000', 'Trivandrum', '60  & above year', 'Male', 'Rs. 1 to less than 3 lakh', 'Vattiyoorkavu', 'Graduate', '3 or 4', 3.0, 'Retired/Pensioners', 'Worsened', 'Will improve', 'Decreased', 'Will increase', 'Decreased', 'Will increase', 'Decreased', 'Remain the same', 'Decreased', 'Will increase', 'Worsened', 'Will improve', 'Remained the same', 'Will decrease', None, None), (5319, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, ...
# 2021-02-23 22:43:11,454 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 22:43:11,457 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-02-23 22:43:11,457 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:13,005 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CCS")
# 2021-02-23 22:43:13,005 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:13,017 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 22:43:13,114 INFO sqlalchemy.engine.base.Engine INSERT INTO "CCS" ("index", "Index", "Round", "Period", "City", "Age", "Gender", "Annual Income", "Assembly Constituency Name", "Educational Qualification", "No. of Family Members", "No. of Earning members in the family", "Occupation of Respondent", "Perception on General Economic condition - compared to one year ago", "Outlook on General Economic condition - one year ahead", "Perception on Household income - compared to one year ago", "Outlook on Household income - one year ahead", "Perception on Household spending - compared to one year ago", "Outlook on Household spending - one year ahead", "Perception on essential spending - compared to one year ago", "Outlook on essential spending - one year ahead", "Perception on non-essential spending - compared to one year ago", "Outlook on non-essential spending - one year ahead", "Perception on Employment scenario - compared to one year ago", "Outlook on Employment scenario - one year ahead", "Perception on General prices - compared to one year ago", "Outlook on General prices - one year ahead", "Perception on Inflation - compared to one year ago", "Outlook on Inflation - one year ahead") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 22:43:13,115 INFO sqlalchemy.engine.base.Engine ((0, 1.0, 43.0, '2018-06-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amaraiwadi ', '10th Std-Below 12th Std', '1 to 2', 1.0, 'House wife', 'Remained the same', 'Will worsen', 'Decreased', 'Remain the same', 'Increased', 'Will decrease', 'Increased', 'Will increase', 'Decreased', 'Will decrease', 'Improved', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (1, 2.0, 43.0, '2018-06-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amaraiwadi ', '5th Std-Below 10th Std', '5 and more', 2.0, 'Daily worker', 'Remained the same', 'Will improve', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will improve', 'Increased', 'Will decrease', 'Increased', None), (2, 3.0, 43.0, '2018-06-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amaraiwadi ', 'Graduate', '3 or 4', 1.0, 'House wife', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (3, 4.0, 43.0, '2018-06-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amaraiwadi ', 'Post Graduate', '5 and more', 3.0, 'House wife', 'Improved', 'Will improve', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Worsened', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (4, 5.0, 43.0, '2018-06-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bapunagar ', 'Below 5th Std', '5 and more', 4.0, 'House wife', 'Improved', 'Remain the same', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Remain the same', 'Remained the same', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (5, 6.0, 43.0, '2018-06-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bapunagar ', 'Illiterate', '5 and more', 2.0, 'House wife', 'Improved', 'Will improve', 'Increased', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Remain the same', 'Increased', 'Remain the same', 'Increased', None), (6, 7.0, 43.0, '2018-06-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Ellisbridge ', '5th Std-Below 10th Std', '1 to 2', 1.0, 'House wife', 'Improved', 'Will improve', 'Decreased', 'Will increase', 'Remained the same', 'Will increase', 'Remained the same', 'Will increase', 'Remained the same', 'Will increase', 'Remained the same', 'Will improve', 'Increased', 'Will decrease', 'Increased', None), (7, 8.0, 43.0, '2018-06-30 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Ghatlodiya ', '10th Std-Below 12th Std', '3 or 4', 1.0, 'House wife', 'Worsened', 'Remain the same', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Worsened', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase')  ... displaying 10 of 6506 total bound parameter sets ...  (6504, 6505.0, 43.0, '2018-06-30 00:00:00.000000', 'Trivandrum', '60  & above year', 'Male', 'Rs. 5 lakh or more', 'Vattiyoorkavu', 'Post Graduate', '3 or 4', 2.0, 'Retired/Pensioners', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Remain the same', 'Decreased', None), (6505, None, None, None, None, None, None, None, None, None, None, None, None, None, None,  ...
# 2021-02-23 22:43:13,140 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 22:43:13,144 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-02-23 22:43:13,144 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:14,506 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CCS")
# 2021-02-23 22:43:14,507 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:14,518 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 22:43:14,599 INFO sqlalchemy.engine.base.Engine INSERT INTO "CCS" ("index", "Index", "Round", "Period", "City", "Age", "Gender", "Annual Income", "Assembly Constituency Name", "Educational Qualification", "No. of Family Members", "No. of Earning members in the family", "Occupation of Respondent", "Perception on General Economic condition - compared to one year ago", "Outlook on General Economic condition - one year ahead", "Perception on Household income - compared to one year ago", "Outlook on Household income - one year ahead", "Perception on Household spending - compared to one year ago", "Outlook on Household spending - one year ahead", "Perception on essential spending - compared to one year ago", "Outlook on essential spending - one year ahead", "Perception on non-essential spending - compared to one year ago", "Outlook on non-essential spending - one year ahead", "Perception on Employment scenario - compared to one year ago", "Outlook on Employment scenario - one year ahead", "Perception on General prices - compared to one year ago", "Outlook on General prices - one year ahead", "Perception on Inflation - compared to one year ago", "Outlook on Inflation - one year ahead") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# ...
# 2021-02-23 22:43:45,811 INFO sqlalchemy.engine.base.Engine ((0, 1.0, 32.0, '2016-09-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Basavanagudi', 'Graduate & above', '1 to 2', 1.0, 'House wife', 'Improved', 'Will improve', 'Remained the same', 'Will increase', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Improved', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (1, 2.0, 32.0, '2016-09-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bommanahalli', 'Below graduate', '3 or 4', 1.0, 'House wife', 'Improved', 'Will improve', 'Increased', 'Remain the same', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Remained the same', 'Will increase', 'Improved', 'Remain the same', 'Decreased', 'Will decrease', None, None), (2, 3.0, 32.0, '2016-09-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bommanahalli', 'Below graduate', '3 or 4', 1.0, 'House wife', 'Remained the same', 'Will improve', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Decreased', 'Will increase'), (3, 4.0, 32.0, '2016-09-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bommanahalli', 'Below graduate', '3 or 4', 1.0, 'House wife', 'Worsened', 'Remain the same', 'Increased', 'Remain the same', 'Increased', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Remain the same', 'Remained the same', 'Will improve', 'Remained the same', 'Will increase', None, 'Will increase'), (4, 5.0, 32.0, '2016-09-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bommanahalli', 'Below graduate', '3 or 4', 2.0, 'House wife', 'Improved', 'Will improve', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (5, 6.0, 32.0, '2016-09-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bommanahalli', 'Below graduate', '3 or 4', 3.0, 'House wife', 'Worsened', 'Will worsen', 'Remained the same', 'Will increase', 'Remained the same', 'Remain the same', 'Remained the same', 'Will decrease', 'Remained the same', 'Remain the same', 'Remained the same', 'Will worsen', 'Remained the same', 'Remain the same', None, None), (6, 7.0, 32.0, '2016-09-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bommanahalli', 'Below graduate', '3 or 4', 3.0, 'Unemployed', 'Remained the same', 'Will worsen', 'Remained the same', 'Will decrease', 'Remained the same', 'Remain the same', 'Decreased', 'Will decrease', 'Remained the same', 'Will decrease', 'Remained the same', 'Will worsen', 'Decreased', 'Will decrease', None, None), (7, 8.0, 32.0, '2016-09-30 00:00:00.000000', 'Bengaluru', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bommanahalli', 'Below graduate', '5 and more', 1.0, 'Retired/Pensioners', 'Worsened', 'Remain the same', 'Decreased', 'Remain the same', 'Increased', 'Remain the same', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Worsened', 'Will improve', 'Increased', 'Will increase', 'Remained the same', 'Remain the same')  ... displaying 10 of 4978 total bound parameter sets ...  (4976, 4977.0, 32.0, '2016-09-30 00:00:00.000000', 'Mumbai', '60  & above year', 'Male', 'Rs. 1 to less than 3 lakh', 'Swami Vivekanand Marge, Malad (P.), Mumbai-64,', 'Up to primary', '3 or 4', 2.0, 'Retired/Pensioners', 'Remained the same', 'Will improve', 'Increased', 'Remain the same', 'Increased', 'Remain the same', 'Remained the same', 'Will increase', 'Increased', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the  ...
# 2021-02-23 22:43:45,831 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 22:43:45,834 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-02-23 22:43:45,835 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:47,204 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CCS")
# 2021-02-23 22:43:47,205 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:47,215 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 22:43:47,294 INFO sqlalchemy.engine.base.Engine INSERT INTO "CCS" ("index", "Index", "Round", "Period", "City", "Age", "Gender", "Annual Income", "Assembly Constituency Name", "Educational Qualification", "No. of Family Members", "No. of Earning members in the family", "Occupation of Respondent", "Perception on General Economic condition - compared to one year ago", "Outlook on General Economic condition - one year ahead", "Perception on Household income - compared to one year ago", "Outlook on Household income - one year ahead", "Perception on Household spending - compared to one year ago", "Outlook on Household spending - one year ahead", "Perception on essential spending - compared to one year ago", "Outlook on essential spending - one year ahead", "Perception on non-essential spending - compared to one year ago", "Outlook on non-essential spending - one year ahead", "Perception on Employment scenario - compared to one year ago", "Outlook on Employment scenario - one year ahead", "Perception on General prices - compared to one year ago", "Outlook on General prices - one year ahead", "Perception on Inflation - compared to one year ago", "Outlook on Inflation - one year ahead") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 22:43:47,294 INFO sqlalchemy.engine.base.Engine ((0, 1.0, 54.0, '2020-05-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amaraiwadi', 'Illiterate', '5 and more', 1.0, 'House wife', 'Worsened', 'Will worsen', 'Decreased', 'Remain the same', 'Decreased', 'Remain the same', 'Decreased', 'Will decrease', 'Remained the same', 'Remain the same', 'Worsened', 'Will worsen', 'Increased', 'Will increase', 'Increased', 'Will increase'), (1, 2.0, 54.0, '2020-05-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', '10th Std-Below 12th Std', '1 to 2', 1.0, 'Unemployed', 'Worsened', 'Will improve', 'Increased', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Remain the same', 'Worsened', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (2, 3.0, 54.0, '2020-05-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', '10th Std-Below 12th Std', '3 or 4', 1.0, 'Employed', 'Improved', 'Will improve', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Decreased', 'Will decrease', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (3, 4.0, 54.0, '2020-05-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', '10th Std-Below 12th Std', '3 or 4', 1.0, 'House wife', 'Worsened', 'Will improve', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Worsened', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Remain the same'), (4, 5.0, 54.0, '2020-05-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', '12th Std', '5 and more', 4.0, 'Employed', 'Worsened', 'Will worsen', 'Decreased', 'Will increase', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will decrease', 'Worsened', 'Will worsen', 'Increased', 'Will increase', 'Increased', 'Will increase'), (5, 6.0, 54.0, '2020-05-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', 'Graduate', '5 and more', 3.0, 'Employed', 'Worsened', 'Will worsen', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Improved', 'Will worsen', 'Increased', 'Will increase', 'Increased', 'Will increase'), (6, 7.0, 54.0, '2020-05-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Asarwa', 'Graduate', '5 and more', 4.0, 'House wife', 'Worsened', 'Will worsen', 'Decreased', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (7, 8.0, 54.0, '2020-05-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bapunagar', '5th Std-Below 10th Std', '5 and more', 3.0, 'Daily worker', 'Worsened', 'Will worsen', 'Decreased', 'Will increase', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Worsened', 'Will worsen', 'Increased', 'Remain the same', 'Remained the same', None)  ... displaying 10 of 5301 total bound parameter sets ...  (5299, 5300.0, 54.0, '2020-05-31 00:00:00.000000', 'Trivandrum', '60  & above year', 'Male', 'Rs. 1 to less than 3 lakh', 'Vattiyoorkavu', '10th Std-Below 12th Std', '3 or 4', 2.0, 'Retired/Pensioners', 'Worsened', 'Will worsen', 'Remained the same', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Worsened', 'Remain the same', 'Increased', 'Will increase', 'Increased', 'Will increase'), (5300, None, None, None, None, None, None, None, None, None, None, None, None, None, None, Non ...
# 2021-02-23 22:43:47,315 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 22:43:47,319 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-02-23 22:43:47,319 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:48,601 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CCS")
# 2021-02-23 22:43:48,602 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 22:43:48,612 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 22:43:48,693 INFO sqlalchemy.engine.base.Engine INSERT INTO "CCS" ("index", "Index", "Round", "Period", "City", "Age", "Gender", "Annual Income", "Assembly Constituency Name", "Educational Qualification", "No. of Family Members", "No. of Earning members in the family", "Occupation of Respondent", "Perception on General Economic condition - compared to one year ago", "Outlook on General Economic condition - one year ahead", "Perception on Household income - compared to one year ago", "Outlook on Household income - one year ahead", "Perception on Household spending - compared to one year ago", "Outlook on Household spending - one year ahead", "Perception on essential spending - compared to one year ago", "Outlook on essential spending - one year ahead", "Perception on non-essential spending - compared to one year ago", "Outlook on non-essential spending - one year ahead", "Perception on Employment scenario - compared to one year ago", "Outlook on Employment scenario - one year ahead", "Perception on General prices - compared to one year ago", "Outlook on General prices - one year ahead", "Perception on Inflation - compared to one year ago", "Outlook on Inflation - one year ahead") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 22:43:48,694 INFO sqlalchemy.engine.base.Engine ((0, 1.0, 46.0, '2018-12-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Amaraiwadi', 'Graduate', '3 or 4', 1.0, 'House wife', 'Worsened', 'Will improve', 'Decreased', 'Will decrease', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Worsened', 'Will worsen', 'Increased', 'Will increase', 'Increased', 'Will increase'), (1, 2.0, 46.0, '2018-12-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Bapunagar', '5th Std-Below 10th Std', '5 and more', 3.0, 'House wife', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (2, 3.0, 46.0, '2018-12-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Danilimda', '10th Std-Below 12th Std', '3 or 4', 1.0, 'House wife', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Will improve', 'Remained the same', 'Will increase', None, 'Will increase'), (3, 4.0, 46.0, '2018-12-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Danilimda', '10th Std-Below 12th Std', '3 or 4', 1.0, 'House wife', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Remain the same', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (4, 5.0, 46.0, '2018-12-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Danilimda', '12th Std', '5 and more', 1.0, 'House wife', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (5, 6.0, 46.0, '2018-12-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Danilimda', '5th Std-Below 10th Std', '5 and more', 2.0, 'House wife', 'Improved', 'Will improve', 'Remained the same', 'Will increase', 'Remained the same', 'Will increase', 'Increased', 'Will increase', 'Remained the same', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase'), (6, 7.0, 46.0, '2018-12-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Danilimda', 'Graduate', '5 and more', 1.0, 'House wife', 'Remained the same', 'Will improve', 'Decreased', 'Will increase', 'Increased', 'Will increase', 'Decreased', 'Will increase', 'Increased', 'Will increase', 'Worsened', 'Will improve', 'Increased', 'Will decrease', 'Increased', None), (7, 8.0, 46.0, '2018-12-31 00:00:00.000000', 'Ahmedabad', '22-29 year', 'Female', 'Rs. 1 lakh or less', 'Dariyapur', '5th Std-Below 10th Std', '5 and more', 1.0, 'House wife', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Increased', 'Will increase', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Will increase')  ... displaying 10 of 5348 total bound parameter sets ...  (5346, 5347.0, 46.0, '2018-12-31 00:00:00.000000', 'Trivandrum', '60  & above year', 'Male', 'Rs. 5 lakh or more', 'Nemom', 'Post Graduate', '1 to 2', 1.0, 'Retired/Pensioners', 'Remained the same', 'Remain the same', 'Decreased', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Remained the same', 'Remain the same', 'Improved', 'Will improve', 'Increased', 'Will increase', 'Increased', 'Remain the same'), (5347, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, ...
# 2021-02-23 22:43:48,715 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 22:43:48,718 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-02-23 22:43:48,718 INFO sqlalchemy.engine.base.Engine ()
