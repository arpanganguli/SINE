# %%
# import packages

import sqlalchemy as sa
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:////Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS.db'
                       , echo = True) # sqlite:////absolute/path/to/file.db

# %%
query_string = "SELECT * FROM CCS"
df = pd.read_sql(sql=query_string, con=engine)

display(df.head())
# Out:
# 2021-03-01 01:32:57,271 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("SELECT * FROM CCS")
# 2021-03-01 01:32:57,274 INFO sqlalchemy.engine.base.Engine ()
# 2021-03-01 01:32:57,279 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("SELECT * FROM CCS")
# 2021-03-01 01:32:57,282 INFO sqlalchemy.engine.base.Engine ()
# 2021-03-01 01:32:57,287 INFO sqlalchemy.engine.base.OptionEngine SELECT * FROM CCS
# 2021-03-01 01:32:57,289 INFO sqlalchemy.engine.base.OptionEngine ()
#    Index  Round                      Period       City         Age  Gender  \
# 0      0   23.0  2015-03-31 00:00:00.000000  Bengaluru  22-29 year  Female
# 1      1   23.0  2015-03-31 00:00:00.000000  Bengaluru  22-29 year  Female
# 2      2   23.0  2015-03-31 00:00:00.000000  Bengaluru  22-29 year  Female
# 3      3   23.0  2015-03-31 00:00:00.000000  Bengaluru  22-29 year  Female
# 4      4   23.0  2015-03-31 00:00:00.000000  Bengaluru  22-29 year  Female
#
# ...

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173640 entries, 0 to 173639
# Data columns (total 28 columns):
#  #   Column                                                               Non-Null Count   Dtype
# ---  ------                                                               --------------   -----
#  0   Index                                                                173640 non-null  int64
#  1   Round                                                                173608 non-null  float64
#  2   Period                                                               173608 non-null  object
#  3   City                                                                 173608 non-null  object
#  4   Age                                                                  173608 non-null  object
#  5   Gender                                                               173608 non-null  object
# ...
