# %%
# import packages

import pandas as pd
import sqlalchemy as sa
from sqlalchemy.sql import text
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:////Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS.db', echo = True) # sqlite:////absolute/path/to/file.db

# %%
sql_query = sa.text("SELECT * FROM CCS WHERE City = 'Delhi' AND Gender = 'Female'")
pd.read_sql_query(sql_query, con=engine)
# Out:
# 2021-02-23 23:54:21,690 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-02-23 23:54:21,691 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 23:54:21,693 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-02-23 23:54:21,693 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 23:54:21,695 INFO sqlalchemy.engine.base.OptionEngine SELECT * FROM CCS WHERE City = 'Delhi' AND Gender = 'Female'
# 2021-02-23 23:54:21,696 INFO sqlalchemy.engine.base.OptionEngine ()
#         Index  Round                      Period   City               Age  \
# 0      1787.0   23.0  2015-03-31 00:00:00.000000  Delhi        22-29 year
# 1      1788.0   23.0  2015-03-31 00:00:00.000000  Delhi        22-29 year
# 2      1789.0   23.0  2015-03-31 00:00:00.000000  Delhi        22-29 year
# 3      1790.0   23.0  2015-03-31 00:00:00.000000  Delhi        22-29 year
# 4      1791.0   23.0  2015-03-31 00:00:00.000000  Delhi        22-29 year
# ...       ...    ...                         ...    ...               ...
# 10978  2549.0   46.0  2018-12-31 00:00:00.000000  Delhi  60  & above year
# 10979  2550.0   46.0  2018-12-31 00:00:00.000000  Delhi  60  & above year
# 10980  2551.0   46.0  2018-12-31 00:00:00.000000  Delhi  60  & above year
# 10981  2552.0   46.0  2018-12-31 00:00:00.000000  Delhi  60  & above year
# 10982  2553.0   46.0  2018-12-31 00:00:00.000000  Delhi  60  & above year
#
#        Gender              Annual Income Assembly Constituency Name  \
# 0      Female         Rs. 1 lakh or less                  badarpur
# 1      Female         Rs. 1 lakh or less                  balimaran
# 2      Female         Rs. 1 lakh or less                  balimaran
# 3      Female         Rs. 1 lakh or less                  balimaran
# 4      Female         Rs. 1 lakh or less                     bawana
# ...       ...                        ...                        ...
# 10978  Female  Rs. 1 to less than 3 lakh                   WAZIRPUR
# 10979  Female       Rs. 3 lakh to 5 lakh                DELHI CANTT
# 10980  Female       Rs. 3 lakh to 5 lakh                  NEW DELHI
# 10981  Female       Rs. 3 lakh to 5 lakh                  NEW DELHI
# 10982  Female       Rs. 3 lakh to 5 lakh                   SHAHDARA
#
#       Educational Qualification No. of Family Members  ...  \
# 0                 Up to primary            5 and more  ...
# 1                 Up to primary                3 or 4  ...
# 2                 Up to primary            5 and more  ...
# 3                 Up to primary            5 and more  ...
# 4                 Up to primary            5 and more  ...
# ...                         ...                   ...  ...
# 10978                Illiterate            5 and more  ...
# 10979   10th Std-Below 12th Std            5 and more  ...
# 10980                  12th Std            5 and more  ...
# 10981    5th Std-Below 10th Std            5 and more  ...
# 10982   10th Std-Below 12th Std            5 and more  ...
#
#        Perception on essential spending - compared to one year ago  \
# 0                                              Increased
# 1                                      Remained the same
# 2                                              Increased
# 3                                              Increased
# 4                                              Increased
# ...                                                  ...
# 10978                                          Increased
# 10979                                          Increased
# 10980                                          Increased
# 10981                                          Increased
# 10982                                          Increased
#
#       Outlook on essential spending - one year ahead  \
# 0                                      Will decrease
# 1                                      Will decrease
# 2                                      Will increase
# 3                                      Will decrease
# 4                                      Will increase
# ...                                              ...
# 10978                                  Will increase
# 10979                                  Will increase
# 10980                                  Will increase
# 10981                                  Will increase
# 10982                                  Will increase
#
#       Perception on non-essential spending - compared to one year ago  \
# 0                                              Increased
# 1                                      Remained the same
# 2                                      Remained the same
# 3                                      Remained the same
# 4                                              Increased
# ...                                                  ...
# 10978                                  Remained the same
# 10979                                          Increased
# 10980                                  Remained the same
# 10981                                  Remained the same
# 10982                                          Increased
#
#       Outlook on non-essential spending - one year ahead  \
# 0                                          Will decrease
# 1                                        Remain the same
# 2                                        Remain the same
# 3                                        Remain the same
# 4                                          Will increase
# ...                                                  ...
# 10978                                      Will increase
# 10979                                      Will increase
# 10980                                    Remain the same
# 10981                                    Remain the same
# 10982                                      Will increase
#
#       Perception on Employment scenario - compared to one year ago  \
# 0                                               Improved
# 1                                               Worsened
# 2                                               Worsened
# 3                                               Worsened
# 4                                      Remained the same
# ...                                                  ...
# 10978                                  Remained the same
# 10979                                           Worsened
# 10980                                           Improved
# 10981                                  Remained the same
# 10982                                  Remained the same
#
#       Outlook on Employment scenario - one year ahead  \
# 0                                        Will improve
# 1                                        Will improve
# 2                                     Remain the same
# 3                                     Remain the same
# 4                                     Remain the same
# ...                                               ...
# 10978                                    Will improve
# 10979                                     Will worsen
# 10980                                 Remain the same
# 10981                                 Remain the same
# 10982                                 Remain the same
#
#       Perception on General prices - compared to one year ago  \
# 0                                              Decreased
# 1                                      Remained the same
# 2                                              Increased
# 3                                              Increased
# 4                                      Remained the same
# ...                                                  ...
# 10978                                          Increased
# 10979                                          Increased
# 10980                                          Increased
# 10981                                  Remained the same
# 10982                                          Decreased
#
#       Outlook on General prices - one year ahead  \
# 0                                  Will increase
# 1                                  Will decrease
# 2                                  Will increase
# 3                                  Will increase
# 4                                  Will increase
# ...                                          ...
# 10978                            Remain the same
# 10979                              Will increase
# 10980                              Will increase
# 10981                            Remain the same
# 10982                              Will decrease
#
#       Perception on Inflation - compared to one year ago  \
# 0                                                   None
# 1                                                   None
# 2                                              Increased
# 3                                              Increased
# 4                                                   None
# ...                                                  ...
# 10978                                          Increased
# 10979                                          Decreased
# 10980                                  Remained the same
# 10981                                               None
# 10982                                               None
#
#       Outlook on Inflation - one year ahead
# 0                             Will decrease
# 1                                      None
# 2                             Will increase
# 3                           Remain the same
# 4                             Will increase
# ...                                     ...
# 10978                                  None
# 10979                       Remain the same
# 10980                       Remain the same
# 10981                                  None
# 10982                                  None
#
# [10983 rows x 28 columns]
