# %%
# import packages

import pandas as pd
import sqlalchemy as sa
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float, NVARCHAR
import os
import glob

# %%
# create SQL database

engine = create_engine('sqlite:////Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS.db', echo = True) # sqlite:////absolute/path/to/file.db

meta = MetaData()

CCS = Table(
    'CCS', meta
    ,Column('Serial No.', Float)
    ,Column('Round No.', Float)
    ,Column('Period', NVARCHAR)
    ,Column('City', NVARCHAR)
    ,Column('Age', NVARCHAR)
    ,Column('Gender', NVARCHAR)
    ,Column('Occupation of Respondent', NVARCHAR)
    ,Column('Annual Income', NVARCHAR)
    ,Column('No. of Family Members', NVARCHAR)
    ,Column('Education Qualification', NVARCHAR)
    ,Column('Number Of Earning Members', NVARCHAR)
    ,Column('Perception on General Economic Condition – compared to one year ago', NVARCHAR)
    ,Column('Outlook on General Economic Condition – one year ahead', NVARCHAR)
    ,Column('Perception on Household Circumstances – compared to one year ago', NVARCHAR)
    ,Column('Outlook on Household Circumstances – one year ahead', NVARCHAR)
    ,Column('Perception on Household Income – compared to one year ago', NVARCHAR)
    ,Column('Outlook on Household Income – one year ahead', NVARCHAR)
    ,Column('Perception on Household Spending – compared to one year ago', NVARCHAR)
    ,Column('Outlook on Household Spending – one year ahead', NVARCHAR)
    ,Column('Perception on Employment Scenario – compared to one year ago', NVARCHAR)
    ,Column('Outlook on Employment Scenario – one year ahead', NVARCHAR)
    ,Column('Perception on General Price Levels – compared to one year ago', NVARCHAR)
    ,Column('Outlook on General Price Levels – one year ahead', NVARCHAR)
    ,Column('Perception on Inflation – compared to one year ago', NVARCHAR)
    ,Column('Outlook on Inflation – one year ahead', NVARCHAR)
    )

meta.create_all(engine)
# Out:
# 2021-02-23 01:20:15,983 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-02-23 01:20:15,983 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 01:20:15,984 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-02-23 01:20:15,984 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 01:20:15,984 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CCS")
# 2021-02-23 01:20:15,985 INFO sqlalchemy.engine.base.Engine ()

# %%
root = r'/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS'

url = []
for root, dirs, files in os.walk(root):
    url += glob.glob(os.path.join(root, '*.xlsx'))
    display(url)
# Out:
# ['/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201503.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201811.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201903.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201606.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201309.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201312.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201611.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201703.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_202011.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201406.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201806.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_202007.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201509.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201909.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201905.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201303.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201712.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201705.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201512.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_202001.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201709.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201209.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201706.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201907.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201403.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201803.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201911.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201506.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_202003.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201212.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201603.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201711.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201612.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201805.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201409.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201809.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_202009.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201609.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_202005.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201412.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201812.xlsx',
#  '/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201306.xlsx']

# %%
for file in url[:5]:
    df = pd.read_excel(file)
    display(df.head(2))
# Out:
#    Serial No.  Unnamed: 1  Round No.     Period       City         Age  \
# 0         1.0         NaN       23.0 2015-03-31  Bengaluru  22-29 year
# 1         2.0         NaN       23.0 2015-03-31  Bengaluru  22-29 year
#
#    Gender       Annual Income  Unnamed: 8 Assembly Constituency Name  ...  \
# 0  Female  Rs. 1 lakh or less         NaN             Batarayanapura  ...
# 1  Female  Rs. 1 lakh or less         NaN             Batarayanapura  ...
#
#    Perception on essential spending - compared to one year ago  \
# 0                                          Increased
# 1                                          Increased
#
#   Outlook on essential spending - one year ahead  \
# 0                                  Will increase
# 1                                  Will increase
#
#   Perception on non-essential spending - compared to one year ago  \
# 0                                          Increased
# 1                                          Decreased
#
#    Outlook on non-essential spending - one year ahead  \
# 0                                      Will increase
# 1                                      Will decrease
#
#   Perception on Employment scenario - compared to one year ago  \
# 0                                           Improved
# 1                                           Improved
#
#   Outlook on Employment scenario - one year ahead  \
# 0                                    Will improve
# 1                                    Will improve
#
#   Perception on General prices - compared to one year ago  \
# 0                                          Increased
# 1                                          Decreased
#
#   Outlook on General prices - one year ahead  \
# 0                              Will increase
# 1                              Will increase
#
#   Perception on Inflation - compared to one year ago  \
# 0                                          Increased
# 1                                                NaN
#
#   Outlook on Inflation - one year ahead
# 0                         Will increase
# 1                         Will increase
#
# [2 rows x 31 columns]
#    Serial No.  Round No.     Period       City         Age  Gender  \
# 0         1.0       45.0 2018-11-30  Ahmedabad  22-29 year  Female
# 1         2.0       45.0 2018-11-30  Ahmedabad  22-29 year  Female
#
#         Annual Income  Unnamed: 7 Assembly Constituency Name  Unnamed: 9  ...  \
# 0  Rs. 1 lakh or less         NaN                 Amaraiwadi         NaN  ...
# 1  Rs. 1 lakh or less         NaN                 Amaraiwadi         NaN  ...
#
#   Perception on essential spending - compared to one year ago  \
# 0                                          Increased
# 1                                          Increased
#
#   Outlook on essential spending - one year ahead  \
# 0                                  Will increase
# 1                                  Will increase
#
#    Perception on non-essential spending - compared to one year ago  \
# 0                                          Increased
# 1                                          Increased
#
#   Outlook on non-essential spending - one year ahead  \
# 0                                      Will increase
# 1                                    Remain the same
#
#   Perception on Employment scenario - compared to one year ago  \
# 0                                           Improved
# 1                                  Remained the same
#
#   Outlook on Employment scenario - one year ahead  \
# 0                                    Will improve
# 1                                    Will improve
#
#   Perception on General prices - compared to one year ago  \
# 0                                  Remained the same
# 1                                  Remained the same
#
#   Outlook on General prices - one year ahead  \
# 0                            Remain the same
# 1                              Will increase
#
#   Perception on Inflation - compared to one year ago  \
# 0                                                NaN
# 1                                                NaN
#
#   Outlook on Inflation - one year ahead
# 0                                   NaN
# 1                       Remain the same
#
# [2 rows x 30 columns]
#    Serial No.  Round No.     Period       City         Age  Gender  \
# 0         1.0       47.0 2019-03-31  Ahmedabad  22-29 year  Female
# 1         2.0       47.0 2019-03-31  Ahmedabad  22-29 year  Female
#
#         Annual Income  Unnamed: 7 Assembly Constituency Name  Unnamed: 9  ...  \
# 0  Rs. 1 lakh or less         NaN                 Amaraiwadi         NaN  ...
# 1  Rs. 1 lakh or less         NaN                 Amaraiwadi         NaN  ...
#
#   Perception on essential spending - compared to one year ago  \
# 0                                  Remained the same
# 1                                          Increased
#
#   Outlook on essential spending - one year ahead  \
# 0                                  Will increase
# 1                                  Will increase
#
#    Perception on non-essential spending - compared to one year ago  \
# 0                                  Remained the same
# 1                                  Remained the same
#
#   Outlook on non-essential spending - one year ahead  \
# 0                                      Will decrease
# 1                                      Will increase
#
#   Perception on Employment scenario - compared to one year ago  \
# 0                                           Improved
# 1                                           Improved
#
#   Outlook on Employment scenario - one year ahead  \
# 0                                    Will improve
# 1                                    Will improve
#
#   Perception on General prices - compared to one year ago  \
# 0                                          Decreased
# 1                                          Increased
#
#   Outlook on General prices - one year ahead  \
# 0                              Will increase
# 1                              Will increase
#
#   Perception on Inflation - compared to one year ago  \
# 0                                                NaN
# 1                                          Increased
#
#   Outlook on Inflation - one year ahead
# 0                         Will increase
# 1                         Will increase
#
# [2 rows x 30 columns]
#    Serial No.  Round No.     Period       City         Age  Gender  \
# 0         1.0       31.0 2016-06-30  Bengaluru  22-29 year  Female
# 1         2.0       31.0 2016-06-30  Bengaluru  22-29 year  Female
#
#         Annual Income  Unnamed: 7 Assembly Constituency Name  Unnamed: 9  ...  \
# 0  Rs. 1 lakh or less         NaN                    Adugodi         NaN  ...
# 1  Rs. 1 lakh or less         NaN                  Bangalore         NaN  ...
#
#   Perception on essential spending - compared to one year ago  \
# 0                                          Increased
# 1                                          Increased
#
#   Outlook on essential spending - one year ahead  \
# 0                                  Will increase
# 1                                  Will increase
#
#    Perception on non-essential spending - compared to one year ago  \
# 0                                          Increased
# 1                                          Decreased
#
#   Outlook on non-essential spending - one year ahead  \
# 0                                      Will increase
# 1                                      Will increase
#
#   Perception on Employment scenario - compared to one year ago  \
# 0                                           Improved
# 1                                           Worsened
#
#   Outlook on Employment scenario - one year ahead  \
# 0                                    Will improve
# 1                                 Remain the same
#
#   Perception on General prices - compared to one year ago  \
# 0                                          Increased
# 1                                          Increased
#
#   Outlook on General prices - one year ahead  \
# 0                              Will increase
# 1                              Will increase
#
#   Perception on Inflation - compared to one year ago  \
# 0                                          Increased
# 1                                          Increased
#
#   Outlook on Inflation - one year ahead
# 0                         Will increase
# 1                         Will increase
#
# [2 rows x 30 columns]
#    Serial No  Round No.  Period   City    Age  Gender  \
# 0        1.0       14.0  SEP-13  Delhi  30-39  Female
# 1        2.0       14.0  SEP-13  Delhi  40-59  Female
#
#   Occupation of Respondent    Annual Income No. of Family Members  \
# 0               House wife  Rs. 1 - 3 lakhs                3 or 4
# 1               House wife  Rs. 1 - 3 lakhs            5 and more
#
#   Education Qualification  ...  \
# 0          Below Graduate  ...
# 1           Up to primary  ...
#
#    Perception on Household Income – compared to one year ago  \
# 0                                          Increased
# 1                                          Increased
#
#   Outlook on Household Income – one year ahead  \
# 0                                     Increase
# 1                                     Increase
#
#   Perception on Household Spending – compared to one year ago  \
# 0                                          Increased
# 1                                          Increased
#
#   Outlook on Household Spending – one year ahead  \
# 0                  Neither increase nor decrease
# 1                                       Decrease
#
#   Perception on Employment Scenario – compared to one year ago  \
# 0                                  Remained the same
# 1                                             Worsen
#
#   Outlook on Employment Scenario – one year ahead  \
# 0                                    Will improve
# 1                            Will Remain the Same
#
#   Perception on General Price Levels – compared to one year ago  \
# 0                                            Gone up
# 1                                            Gone up
#
#   Outlook on General Price Levels – one year ahead  \
# 0                                       Will go up
# 1                                       Will go up
#
#   Perception on Inflation – compared to one year ago  \
# 0                                More than last year
# 1                                More than last year
#
#   Outlook on Inflation – one year ahead
# 0                More than current year
# 1                  Same as current year
#
# [2 rows x 25 columns]
