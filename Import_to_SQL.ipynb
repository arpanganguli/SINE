# %%
# import packages

import pandas as pd
import sqlalchemy as sa
from sqlalchemy import create_engine, Table, Column, Integer, String, MetaData

# %%
# import files

url = r'/Users/arpanganguli/Documents/Professional/Projects/SINE/Database/CCS/CCS_201209.xlsx'
df = pd.read_excel(url)
display(df.head())
# Out:
#    Serial No  Round No.  Period       City    Age  Gender  \
# 0          1         10  SEP-12      Delhi  30-39    Male
# 1          2         10  SEP-12     Mumbai  30-39  Female
# 2          3         10  SEP-12  Bengaluru  22-29  Female
# 3          4         10  SEP-12  Bengaluru  40-59    Male
# 4          5         10  SEP-12     Mumbai  40-59  Female
#
#   Occupation of Respondent    Annual Income No. of Family Members  \
# 0   Self employed/Business  Rs. 1 - 3 lakhs            5 and more
# 1   Self employed/Business  Rs. 3 - 5 lakhs            5 and more
# 2   Self employed/Business  Rs. 1 - 3 lakhs                3 or 4
# 3   Self employed/Business  Rs. 1 - 3 lakhs                3 or 4
# 4               House wife  Rs. 1 - 3 lakhs            5 and more
#
#   Education Qualification  ...  \
# 0          Below Graduate  ...
# 1          Below Graduate  ...
# 2           Up to primary  ...
# 3          Below Graduate  ...
# 4          Below Graduate  ...
#
# ...

# %%
# create SQL database

# %%
meta = MetaData()

CCS = Table(
    'CCS', meta,
     Column('Serial No', Integer)
    ,Column('Round No.', Integer)
)

# %%
engine = create_engine('mysql+pymysql://arpanganguli:arpanganguli@localhost/CCS') # format: mysql://user:pass@host/db
